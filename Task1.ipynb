# %% [markdown]
# <a href="https://colab.research.google.com/github/IT21181474/DL_Lab1/blob/main/Task1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Task1
import numpy as np
import matplotlib.pyplot as plt

arr = np.random.exponential(scale=1.0, size=(4, 4))
arr
# Out:
# array([[0.71683791, 0.71444924, 0.31170237, 0.6333246 ],
#        [0.55154644, 1.65078399, 1.37016926, 0.43056919],
#        [0.35275036, 0.49639487, 0.34236061, 0.0995395 ],
#        [1.37832473, 0.85620021, 0.56202509, 0.13585787]])

# %%
arr2 = np.random.exponential(scale=1.0, size=1000)
arr2
# Out:
# array([2.92955635e-01, 7.40480304e-03, 1.70679468e+00, 3.53835439e-01,
#        1.77836273e+00, 2.45986244e+00, 9.54972777e-01, 3.23978527e+00,
#        1.66019132e+00, 7.41856650e-01, 1.09341043e-01, 6.83157346e-01,
#        1.20414675e-01, 2.53822657e+00, 1.14441178e-01, 1.10077602e+00,
#        2.24502412e+00, 1.34616024e+00, 7.87434648e-01, 3.07588140e+00,
#        1.86267366e+00, 2.93663824e-01, 2.28592349e-01, 2.31731038e-01,
#        2.54483157e-01, 7.26898712e-01, 1.24334226e-01, 2.78254516e-01,
#        2.14794018e-01, 1.38203199e+00, 1.99199297e+00, 8.39930978e-01,
#        4.13903410e-01, 3.84740614e-01, 8.85717913e-01, 1.43698114e+00,
#        3.58685119e+00, 7.12752668e-01, 6.82547997e-01, 9.27848031e-01,
#        3.67396672e-01, 2.70474276e-01, 3.64546117e-01, 3.42474663e-01,
#        7.52258870e-01, 8.01689194e-01, 3.27263534e-01, 1.42458541e+00,
#        4.35767954e+00, 1.33899644e-01, 9.49102394e-01, 1.78814547e+00,
# ...

# %%
# Histogram plot
plt.figure(figsize=(8, 6))
plt.hist(arr2, bins=25, density=True, alpha=0.6, color='b')
plt.title('Random Distribution')
plt.xlabel('Value')
plt.ylabel('Density')
plt.show()

# %%
# 3D plot of Z = X**2 + Y**2
from mpl_toolkits.mplot3d import Axes3D

x = np.linspace(-5, 5, 100)
y = np.linspace(-5, 5, 100)
X, Y = np.meshgrid(x, y)
Z = X**2 + Y**2

fig = plt.figure(figsize=(10, 7))
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(X, Y, Z, cmap='viridis')

ax.set_title('3D Plot of Z = X^2 + Y^2')
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')

plt.show()

# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Load the dataset (assuming seaborn has a Pokémon dataset)
# Replace with the actual path or method to load your dataset
# For demonstration purposes, we will create a small sample dataframe

# Sample data for demonstration, replace this with actual dataset loading
data = {
    'HP': [45, 60, 80, 80, 39, 58, 78, 78, 78],
    'Attack': [49, 62, 82, 100, 52, 64, 84, 130, 104],
    'Defense': [49, 63, 83, 123, 43, 58, 78, 111, 78],
    'Sp. Atk': [65, 80, 100, 122, 60, 80, 109, 130, 159],
    'Sp. Def': [65, 80, 100, 120, 50, 65, 85, 85, 115],
    'Speed': [45, 60, 80, 80, 65, 80, 100, 100, 100]
}
df = pd.DataFrame(data)

# Calculate Pearson correlation
pearson_corr = df.corr(method='pearson')

# Calculate Spearman rank correlation
spearman_corr = df.corr(method='spearman')

# Plotting the Pearson correlation heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(pearson_corr, annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.title('Pearson Correlation Heatmap')
plt.show()

# Plotting the Spearman correlation heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(spearman_corr, annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.title('Spearman Correlation Heatmap')
plt.show()
